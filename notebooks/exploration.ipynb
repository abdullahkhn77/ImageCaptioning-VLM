# %% [markdown]
# # VLM Fine-Tuning Exploration Notebook
#
# This notebook is for exploring the dataset, model behavior, and experiment results.

# %%
# Example: Load and visualize data
import pandas as pd
import json
from PIL import Image
import matplotlib.pyplot as plt

# Load dataset
with open('../data/processed/train.json', 'r') as f:
    data = json.load(f)

print(f"Total samples: {len(data)}")
print(f"Sample caption: {data[0]['caption']}")

# %%
# Example: Test model inference
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image

processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# Load and process image
image = Image.open("path/to/image.jpg").convert('RGB')
inputs = processor(images=image, return_tensors="pt")

# Generate caption
outputs = model.generate(**inputs)
caption = processor.decode(outputs[0], skip_special_tokens=True)
print(f"Caption: {caption}")
